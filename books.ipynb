# %% [markdown]
# <a href="https://colab.research.google.com/github/stev3j/MachineLearning_Practice/blob/main/books.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
gdown.download('https://bit.ly/2eecMKZ', '서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/2eecMKZ
# To: /content/남산도서관 장서 대출목록 (2021년 04월).csv
# 22.8kB [00:00, 63.0kB/s]
# '남산도서관 장서 대출목록 (2021년 04월).csv'

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv') as f:
  print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-6accade1ffbc> in <module>
#       1 with open('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv') as f:
# ----> 2   print(f.readline())
#
# /usr/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte

# %%
import chardet
with open('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv', mode='rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv', encoding='EUC-KR') as f:
  print(f.readline())
  print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","천사를 거부하는 우울한 연인에게 :양안다 시집","지은이: 양안다","문학동네","2023","9788954699334","","0","","811.7","1","0","2023-02-28",

# %%
import pandas as pd
import csv

df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv', encoding='EUC-KR', dtype = {'ISBN': str, '세트 ISBN': str, '주제분류번호': str}, quoting=3, error_bad_lines=False)
# Out:
# <ipython-input-34-ce5ffd57244a>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 02월).csv', encoding='EUC-KR', dtype = {'ISBN': str, '세트 ISBN': str, '주제분류번호': str}, quoting=3, error_bad_lines=False)
# ...

# %%
df.head()
# Out:
#      번호                          도서명               저자       출판사    발행년도  \
# 0   "1"  "천사를 거부하는 우울한 연인에게 :양안다 시집"       "지은이: 양안다"    "문학동네"  "2023"
# 1   "3"           "건강기능식품 약일까? 독일까?"       "김승환 외 지음"  "지식과감성#"  "2022"
# 2   "4"         "인생을 숙제처럼 살지 않기로 했다"  "웃따(나예랑) (지은이)"    "다산북스"  "2023"
# 3   "9"           "여자는 존재 자체로 낙인이었어"         "오현세 지음"    "달콤한책"  "2022"
# 4  "11"                   "크리스마스 타일"         "김금희 지음"      "창비"  "2022"
#
#               ISBN 세트 ISBN 부가기호   권   주제분류번호 도서권수 대출건수          등록일자  \
# 0  "9788954699334"      ""  "0"  ""  "811.7"  "1"  "0"  "2023-02-28"
# 1  "9791139207378"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 2  "9791130696942"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 3  "9791196280178"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 4  "9788936438890"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202302.csv')

# %%
with open('ns_202302.csv') as f:
  for i in range(3):
    print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,"""1""","""천사를 거부하는 우울한 연인에게 :양안다 시집""","""지은이: 양안다""","""문학동네""","""2023""","""9788954699334""","""""","""0""","""""","""811.7""","""1""","""0""","""2023-02-28""",
# 1,"""3""","""건강기능식품 약일까? 독일까?""","""김승환 외 지음""","""지식과감성#""","""2022""","""9791139207378""","""""","""""","""""","""""","""1""","""0""","""2023-02-27""",

# %%
ns_df = pd.read_csv('ns_202302.csv', low_memory = False)
ns_df.head()
# Out:
#    Unnamed: 0    번호                          도서명               저자       출판사  \
# 0           0   "1"  "천사를 거부하는 우울한 연인에게 :양안다 시집"       "지은이: 양안다"    "문학동네"
# 1           1   "3"           "건강기능식품 약일까? 독일까?"       "김승환 외 지음"  "지식과감성#"
# 2           2   "4"         "인생을 숙제처럼 살지 않기로 했다"  "웃따(나예랑) (지은이)"    "다산북스"
# 3           3   "9"           "여자는 존재 자체로 낙인이었어"         "오현세 지음"    "달콤한책"
# 4           4  "11"                   "크리스마스 타일"         "김금희 지음"      "창비"
#
#      발행년도             ISBN 세트 ISBN 부가기호   권   주제분류번호 도서권수 대출건수          등록일자  \
# 0  "2023"  "9788954699334"      ""  "0"  ""  "811.7"  "1"  "0"  "2023-02-28"
# 1  "2022"  "9791139207378"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 2  "2023"  "9791130696942"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 3  "2022"  "9791196280178"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
# 4  "2022"  "9788936438890"      ""   ""  ""       ""  "1"  "0"  "2023-02-27"
#
#    Unnamed: 13
# 0          NaN
# ...

# %%
df.to_csv('ns_202302.csv', index = False)
